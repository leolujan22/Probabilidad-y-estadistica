# %% [markdown]
# <a href="https://colab.research.google.com/github/leolujan22/Probabilidad-y-estadistica/blob/main/UNIDAD%201/Practica4y5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![LOGO_ITD.png](data:image/png;base64,...)
# #PROBABILIDAD Y ESTADISTICA
#
# ## UNIDAD 1
#
# Leonardo Sebastian Lujan Mesta
#
# Dr. Jose Gabriel Rivas Rodriguez
#
# 2Z

# %%
import random

edades = []

for i in range (100):

  numero_aleatorio = random.randint( 18, 70)

  edades.append(numero_aleatorio)
print(edades)
# Out:
# [44, 26, 33, 39, 36, 48, 64, 51, 22, 69, 58, 30, 62, 20, 55, 30, 32, 36, 43, 52, 59, 30, 67, 41, 19, 33, 58, 59, 50, 22, 46, 25, 43, 42, 64, 19, 40, 20, 43, 64, 44, 62, 50, 34, 67, 36, 35, 63, 22, 23, 45, 48, 20, 64, 18, 61, 41, 40, 54, 44, 21, 59, 28, 31, 49, 29, 41, 46, 68, 26, 68, 56, 19, 21, 69, 20, 68, 69, 57, 33, 26, 69, 30, 70, 24, 27, 49, 64, 25, 58, 59, 29, 30, 64, 67, 55, 44, 60, 52, 52]

# %%
import pandas as pd

# %%
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    44
# 1    26
# 2    33
# 3    39
# 4    36

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

print('Tabla de Distribuciones de frecuencias')
tabla_frecuencias.head()
# Out:
# Tabla de Distribuciones de frecuencias
#     Edad  Frecuencia
# 42    18           1
# 16    19           3
# 3     20           4
# 19    21           2
# 6     22           3

# %%
tabla_frecuencias['Frec Relativa']= tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 42    18           1           0.01
# 16    19           3           0.03
# 3     20           4           0.04
# 19    21           2           0.02
# 6     22           3           0.03
# 44    23           1           0.01
# 30    24           1           0.01
# 21    25           2           0.02
# 9     26           3           0.03
# 29    27           1           0.01
# 38    28           1           0.01
# 17    29           2           0.02
# 1     30           5           0.05
# 37    31           1           0.01
# 39    32           1           0.01
# 13    33           3           0.03
# 27    34           1           0.01
# 28    35           1           0.01
# 7     36           3           0.03
# 34    39           1           0.01
# 20    40           2           0.02
# 15    41           3           0.03
# 35    42           1           0.01
# 11    43           3           0.03
# 5     44           4           0.04
# 43    45           1           0.01
# 22    46           2           0.02
# 25    48           2           0.02
# 18    49           2           0.02
# 23    50           2           0.02
# 36    51           1           0.01
# 12    52           3           0.03
# 40    54           1           0.01
# 24    55           2           0.02
# 33    56           1           0.01
# 32    57           1           0.01
# 8     58           3           0.03
# 2     59           4           0.04
# 46    60           1           0.01
# 41    61           1           0.01
# 26    62           2           0.02
# 45    63           1           0.01
# 0     64           6           0.06
# 14    67           3           0.03
# 10    68           3           0.03
# 4     69           4           0.04
# 31    70           1           0.01

# %%
import math

# %%
print(edades)
# Out:
# [44, 26, 33, 39, 36, 48, 64, 51, 22, 69, 58, 30, 62, 20, 55, 30, 32, 36, 43, 52, 59, 30, 67, 41, 19, 33, 58, 59, 50, 22, 46, 25, 43, 42, 64, 19, 40, 20, 43, 64, 44, 62, 50, 34, 67, 36, 35, 63, 22, 23, 45, 48, 20, 64, 18, 61, 41, 40, 54, 44, 21, 59, 28, 31, 49, 29, 41, 46, 68, 26, 68, 56, 19, 21, 69, 20, 68, 69, 57, 33, 26, 69, 30, 70, 24, 27, 49, 64, 25, 58, 59, 29, 30, 64, 67, 55, 44, 60, 52, 52]

# %%
#Crear dataframe con las edades
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     44
# 1     26
# 2     33
# 3     39
# 4     36
# ..   ...
# 95    55
# 96    44
# 97    60
# 98    52
# 99    52
#
# [100 rows x 1 columns]

# %%
#Calcular el numero de intervalos utilizando la regla de sturges
n = len(edades)
k=int(1+math.log2(100))
print("Valor de n = ",n, "\nNumero de intervalos =", k)
# Out:
# Valor de n =  100
# Numero de intervalos = 7

# %%
#Crear la tabla de frecuencia
tabla_frecuencias = pd.cut(df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ['Clase', 'Frec']
tabla_frecuencias
# Out:
#               Clase  Frec
# 0    (62.571, 70.0]    18
# 1  (17.947, 25.429]    17
# 2  (25.429, 32.857]    14
# 3  (40.286, 47.714]    14
# 4  (47.714, 55.143]    13
# 5  (55.143, 62.571]    13
# 6  (32.857, 40.286]    11

# %%
#Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencias = tabla_frecuencias.sort_values(by='Clase')
tabla_frecuencias
# Out:
#               Clase  Frec
# 1  (17.947, 25.429]    17
# 2  (25.429, 32.857]    14
# 6  (32.857, 40.286]    11
# 3  (40.286, 47.714]    14
# 4  (47.714, 55.143]    13
# 5  (55.143, 62.571]    13
# 0    (62.571, 70.0]    18

# %%
tabla_frecuencias['Frec Rel']= tabla_frecuencias['Frec']/n
tabla_frecuencias['Frec Porc']= tabla_frecuencias['Frec']/n* 100
tabla_frecuencias['Frec Ac']= tabla_frecuencias['Frec'].cumsum()
tabla_frecuencias['Frec Rel Ac']= tabla_frecuencias['Frec Porc'].cumsum()
tabla_frecuencias['Frec Porc Ac']= tabla_frecuencias['Frec Porc'].cumsum()
print("Tabla de frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de frecuencias:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 1  (17.947, 25.429]    17      0.17       17.0       17         17.0
# 2  (25.429, 32.857]    14      0.14       14.0       31         31.0
# 6  (32.857, 40.286]    11      0.11       11.0       42         42.0
# 3  (40.286, 47.714]    14      0.14       14.0       56         56.0
# 4  (47.714, 55.143]    13      0.13       13.0       69         69.0
# 5  (55.143, 62.571]    13      0.13       13.0       82         82.0
# 0    (62.571, 70.0]    18      0.18       18.0      100        100.0
#
#    Frec Porc Ac
# 1          17.0
# 2          31.0
# 6          42.0
# 3          56.0
# 4          69.0
# 5          82.0
# 0         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con')

# %%
#Crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins =k, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #PRACTICA 5: DIAGRAMA DE CAJAS Y BIGOTES

# %%
edades2=[]
for i in range(100):
  numero_aleatorio=random.randint(20,87)
  edades2.append(numero_aleatorio)
print(edades2)
# Out:
# [54, 40, 80, 42, 54, 22, 77, 52, 79, 50, 33, 44, 59, 74, 64, 46, 60, 81, 67, 52, 65, 82, 29, 57, 25, 85, 24, 20, 75, 56, 86, 27, 76, 76, 62, 25, 31, 68, 47, 74, 77, 51, 49, 84, 43, 75, 36, 82, 26, 87, 34, 40, 62, 57, 48, 64, 79, 53, 38, 64, 75, 64, 59, 38, 55, 20, 50, 23, 73, 86, 57, 36, 84, 56, 76, 77, 57, 25, 68, 82, 22, 70, 34, 36, 28, 60, 40, 76, 48, 47, 52, 78, 28, 76, 25, 27, 50, 72, 78, 20]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')

plt.show()

# %%
#Agregar una edad mas a la lista de edades2
edades.append(130)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')

plt.show()
