# %% [markdown]
# <a href="https://colab.research.google.com/github/leolujan22/Probabilidad-y-estadistica/blob/main/UNIDAD%201/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![LOGO_ITD.png](data:image/png;base64,...)
#
# #PROBABILIDAD Y ESTADISTICA
#
# ## UNIDAD 1
#
# Leonardo Sebastian Lujan Mesta
#
# Dr. Jose Gabriel Rivas Rodriguez
#
# 2Z

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range (100):
  numero_aleatorio = round( random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [75.69, 69.43, 60.81, 51.54, 98.6, 67.16, 81.49, 85.31, 59.67, 55.46, 63.75, 73.45, 74.65, 66.25, 99.6, 90.36, 76.83, 61.97, 77.48, 84.0, 85.53, 51.82, 95.98, 96.23, 70.57, 98.23, 56.31, 98.71, 72.64, 72.76, 82.76, 83.65, 93.25, 68.97, 82.74, 80.0, 88.45, 77.11, 92.18, 87.92, 95.1, 73.42, 96.37, 69.03, 81.97, 79.73, 92.02, 78.16, 93.5, 95.07, 65.55, 90.9, 93.7, 77.79, 94.97, 74.27, 51.81, 92.26, 60.77, 97.03, 65.5, 90.41, 92.88, 82.62, 67.76, 99.61, 66.55, 99.19, 86.6, 92.9, 70.06, 70.86, 87.4, 81.72, 93.86, 71.99, 58.66, 62.64, 54.58, 67.94, 92.76, 63.17, 98.56, 82.81, 97.47, 93.17, 58.1, 66.7, 80.79, 58.23, 92.9, 75.17, 69.64, 89.97, 55.61, 79.83, 95.89, 81.33, 57.77, 90.73]

# %%
fabrica2 = []
for i in range (100):
  numero_aleatorio = round( random.uniform(50,100),2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [92.84, 53.55, 85.05, 99.85, 69.68, 73.36, 51.83, 64.31, 89.01, 94.01, 52.29, 64.18, 68.94, 65.85, 70.24, 87.64, 90.17, 86.15, 89.78, 92.08, 83.81, 50.5, 52.0, 96.58, 84.14, 83.5, 73.14, 73.47, 73.1, 89.14, 87.9, 82.99, 58.48, 54.85, 84.08, 88.44, 98.25, 77.43, 51.72, 98.22, 95.94, 94.99, 56.18, 66.62, 64.63, 65.48, 82.55, 71.84, 85.69, 84.25, 88.4, 92.32, 98.1, 58.73, 66.31, 59.08, 72.98, 88.01, 75.29, 69.01, 53.55, 59.77, 62.69, 77.32, 56.39, 57.27, 62.69, 66.37, 74.29, 64.56, 67.34, 89.84, 63.23, 98.32, 58.2, 72.38, 72.02, 74.97, 71.63, 65.16, 94.32, 87.62, 91.78, 87.81, 62.04, 60.94, 55.97, 87.48, 74.35, 60.84, 55.55, 80.07, 52.03, 83.3, 71.47, 62.58, 91.14, 88.21, 92.84, 95.06]

# %% [markdown]
# #MAXIMO, MINIMO Y RANGO

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Estadistica descriptiva de la Fabrica 1 \n", "Media = ", media1,
      "\n Mediana = ", mediana1, "\n Moda = ", moda1, "\n Maximo = ", maximo1,
      "\n Minimo = ", minimo1, "\n Rango = ", rango1)
# Out:
# Estadistica descriptiva de la Fabrica 1
#  Media =  79.0706
#  Mediana =  80.39500000000001
#  Moda =  92.9
#  Maximo =  99.61
#  Minimo =  51.54
#  Rango =  48.07

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Estadistica descriptiva de la Fabrica 2 \n", "Media = ", media2,
      "\n Mediana = ", mediana2, "\n Moda = ", moda2, "\n Maximo = ", maximo2,
      "\n Minimo = ", minimo2, "\n Rango = ", rango2)
# Out:
# Estadistica descriptiva de la Fabrica 2
#  Media =  75.2234
#  Mediana =  73.41499999999999
#  Moda =  92.84
#  Maximo =  99.85
#  Minimo =  50.5
#  Rango =  49.349999999999994

# %% [markdown]
# #DISPERSION DE DATOS

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print("Desviacion Estandar Fabrica 1 = ", desviacion_estandar_fabrica1)
# Out:
# Desviacion Estandar Fabrica 1 =  13.943249829145994

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print("Desviacion Estandar Fabrica 2 = ", desviacion_estandar_fabrica2)
# Out:
# Desviacion Estandar Fabrica 2 =  14.39393132644112

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2, label=f'desv. estandar={desviacion_estandar_fabrica1:.2f}')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'moda={moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2, label=f'desv. estandar={desviacion_estandar_fabrica2:.2f}')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diria de la fabrica 2")
plt.legend()
plt.show()

# %%
import seaborn as sns

sns.histplot(x=fabrica1, kde=True, kde_kws={'bw_adjust': 0.5}, bins = 10)
# Out:
# <Axes: ylabel='Count'>
